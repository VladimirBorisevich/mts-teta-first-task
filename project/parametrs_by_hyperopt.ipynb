# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.metrics import mean_absolute_error
from hyperopt import hp, tpe, Trials
from hyperopt.fmin import fmin
import hyperopt
import lightgbm as lgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, r2_score as r2_score
import warnings
warnings.filterwarnings('ignore')


df = pd.read_csv('data/all_v2.csv')
df.head()
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
#      price        date      time    geo_lat    geo_lon  region  building_type  \
# 0  6050000  2018-02-19  20:00:21  59.805808  30.376141    2661              1
# 1  8650000  2018-02-27  12:04:54  55.683807  37.297405      81              3
# 2  4000000  2018-02-28  15:44:00  56.295250  44.061637    2871              1
# 3  1850000  2018-03-01  11:24:52  44.996132  39.074783    2843              4
# 4  5450000  2018-03-01  17:42:43  55.918767  37.984642      81              3
#
#    level  levels  rooms  area  kitchen_area  object_type
# 0      8      10      3  82.6          10.8            1
# 1      5      24      2  69.1          12.0            1
# 2      5       9      3  66.0          10.0            1
# 3     12      16      2  38.0           5.0           11
# 4     13      14      2  60.0          10.0            1

# %% [markdown]
# # Preprocess data

# %%
df = df.query('price > 100000')
df = df.query('price < 500000000')
df = df.query('rooms != -2')
df.index = np.arange(df.shape[0])

df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df = df.sort_values(by='date')
df['year'] = df['date'].dt.year
del df['date'], df['time']


categoricals = ['building_type', 'object_type', 'region', 'year']

# %%
def calc_mean_room_area(df):
    return (df['area'] - df['kitchen_area']) / (abs(df['rooms']))

# %%
df['mean_room_area'] = calc_mean_room_area(df)
df['percent_of_kitchen_area'] = df['kitchen_area'] / df['area']
df['percent_of_level'] = df['level'] / df['levels']

# %%
for col in categoricals:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

# %%
# данные отсортированы по времени
# для отложенной выборки возьмём 100000 последних примеров
df_test = df.iloc[df.index[-100000:]]
df = df.iloc[df.index[:-100000]]

print(f"Test target mean value : {df_test['price'].mean()}")
print(f"Train target mean value : {df['price'].mean()}")
# Out:
# Test target mean value : 6137584.3326
# Train target mean value : 4361977.834525038

# %%
thr = 5e6
expensive_regions = df.groupby('region')['price'].mean().index[df.groupby('region')['price'].mean() > thr]
df['expensive_region'] = df['region'].apply(lambda x: x in expensive_regions).astype(np.int8)
df_test['expensive_region'] = df_test['region'].apply(lambda x: x in expensive_regions).astype(np.int8)

# %%
df_test.index = np.arange(df_test.shape[0])

# %% [markdown]
# # Utils

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))


def pred_map(pred_df):
    MAE = mean_absolute_error(pred_df['y_true'], pred_df['y_pred'])
    RMSE = rmse(pred_df['y_true'], pred_df['y_pred'])
    R2 = r2_score(pred_df['y_true'], pred_df['y_pred'])
    plt.figure(figsize=(8,8))
    ax = plt.subplot(111)
    ax.scatter('y_true', 'y_pred', data=pred_df)
    ax.set_xlabel('True Value', fontsize=15)
    ax.set_ylabel('Predicted Value', fontsize=15)
    ax.set_xlim(pred_df.min().min()-0.1 , pred_df.max().max()+0.1)
    ax.set_ylim(pred_df.min().min()-0.1 , pred_df.max().max()+0.1)
    x = np.linspace(pred_df.min().min()-0.1, pred_df.max().max()+0.1, 2)
    y = x
    ax.plot(x,y,'r-')
    plt.text(0.1, 0.9, 'MAE = {}'.format(str(round(MAE, 5))), transform=ax.transAxes, fontsize=15)
    plt.text(0.1, 0.8, 'RMSE = {}'.format(str(round(RMSE, 5))), transform=ax.transAxes, fontsize=15)
    plt.text(0.1, 0.7, 'R2 = {}'.format(str(round(R2, 5))), transform=ax.transAxes, fontsize=15)

# %%
#check if given parameter can be interpreted as a numerical value
def is_number(s):
    if s is None:
        return False
    try:
        float(s)
        return True
    except ValueError:
        return False

#convert given set of paramaters to integer values
#this at least cuts the excess float decimals if they are there
def convert_int_params(names, params):
    for int_type in names:
        #sometimes the parameters can be choices between options or numerical values. like "log2" vs "1-10"
        raw_val = params[int_type]
        if is_number(raw_val):
            params[int_type] = int(raw_val)
    return params

#convert float parameters to 3 digit precision strings
#just for simpler diplay and all
def convert_float_params(names, params):
    for float_type in names:
        raw_val = params[float_type]
        if is_number(raw_val):
            params[float_type] = '{:.3f}'.format(raw_val)
    return params


# how many CV folds to do on the data
n_folds = 5
# max number of rows to use for X and y. to reduce time and compare options faster
max_n = None
# max number of trials hyperopt runs
n_trials = 200
#verbosity in LGBM is how often progress is printed. with 100=print progress every 100 rounds. 0 is quite?
verbosity = 0
print_summary = False

all_scores = []
all_params = []

# run n_folds of cross validation on the data
# averages fold results
def fit_cv(X, y, params, fit_params):
    # cut the data if max_n is set
    if max_n is not None:
        X = X[:max_n]
        y = y[:max_n]
    
    y = np.array(y)

    score = 0
    folds = KFold(n_splits=n_folds, shuffle=True, random_state=69)

    if print_summary:
        print(f"Running {n_folds} folds...")
    oof_preds = np.zeros((X.shape[0]))
    for i, (train_index, test_index) in enumerate(folds.split(X, y)):
        if verbosity > 0:
            print('-' * 20, f"RUNNING FOLD: {i}/{n_folds}", '-' * 20)

        model = lgb.LGBMRegressor(**params)
        categoricals = ['building_type', 'object_type', 'region', 'year', 'expensive_region']
        X_train, y_train = X.iloc[train_index], y[train_index]
        X_test, y_test = X.iloc[test_index], y[test_index]
        #if 100 it prints progress 100,200,300,... iterations
        model.fit(X_train, y_train, eval_set=(X_test, y_test), 
                  verbose=verbosity, **fit_params, categorical_feature=categoricals)
        oof_preds[test_index] = model.predict(X.iloc[test_index])
        score += mean_absolute_error(y[test_index], oof_preds[test_index])
        importances = model.feature_importances_
        features = X.columns
        
    total_score = score / n_folds
    all_scores.append(total_score)
    all_params.append(params)
    if print_summary:
        print(f"total mae: {total_score}")
    return total_score

def create_fit_params(params):
    using_dart = params['boosting_type'] == "dart"
    if params["objective"] == "rmse":
        # https://github.com/Microsoft/LightGBM/blob/master/docs/Parameters.rst
        fit_params = {"eval_metric": ["rmse"]}
    else:
        fit_params = {"eval_metric": "rmse"}
    if using_dart:
        n_estimators = 2000
    else:
        n_estimators = 10000
        fit_params["early_stopping_rounds"] = 100
    params["n_estimators"] = n_estimators
    return fit_params


# this is the objective function the hyperopt aims to minimize
# i call it objective_sklearn because the lgbm functions called use sklearn API
def objective_sklearn(params):
    int_types = ["num_leaves", "min_child_samples", "subsample_for_bin", "min_data_in_leaf", "bagging_freq"]
    params = convert_int_params(int_types, params)

    # Extract the boosting type
    params['boosting_type'] = params['boosting_type']['boosting_type']
    #    print("running with params:"+str(params))

    fit_params = create_fit_params(params)

    score = fit_cv(X, y, params, fit_params)
    if verbosity == 0:
        if print_summary:
            print("Score {:.3f}".format(score))
    else:
        print("Score {:.3f} params {}".format(score, params))
    result = {"loss": score, "score": score, "params": params, 'status': hyperopt.STATUS_OK}
    return result

def optimize_lgbm(max_n_search=None):
    # https://github.com/Microsoft/LightGBM/blob/master/docs/Parameters.rst
    # https://indico.cern.ch/event/617754/contributions/2590694/attachments/1459648/2254154/catboost_for_CMS.pdf
    space = {
        #this is just piling on most of the possible parameter values for LGBM
        #some of them apparently don't make sense together, but works for now.. :)
        'boosting_type': hp.choice('boosting_type',
                                   [{'boosting_type': 'gbdt',
                                     }]),
        'num_leaves': hp.quniform('num_leaves', 127, 511, 8),
        'learning_rate': hp.uniform('learning_rate', 0.05, 0.2),
        'subsample_for_bin': hp.quniform('subsample_for_bin', 100, 5000, 100),
        'feature_fraction': hp.uniform('feature_fraction', 0.8, 1),
        'bagging_fraction': hp.uniform('bagging_fraction', 0.8, 1), #alias "subsample"
        'min_data_in_leaf': hp.quniform('min_data_in_leaf', 10, 251, 50),
        'lambda_l1': hp.uniform('lambda_l1', 0, 0.3),
        'lambda_l2': hp.uniform('lambda_l2', 0, 0.3),
        'verbose': -1,
        'seed': 42,
        'bagging_freq': hp.quniform('bagging_freq', 1, 30, 5),
        #the LGBM parameters docs list various aliases, and the LGBM implementation seems to complain about
        #the following not being used due to other params, so trying to silence the complaints by setting to None
#         'subsample': None, #overridden by bagging_fraction
#         'reg_alpha': None, #overridden by lambda_l1
#         'reg_lambda': None, #overridden by lambda_l2
        'min_sum_hessian_in_leaf': None, #overrides min_child_weight
        'min_child_samples': None, #overridden by min_data_in_leaf
        'colsample_bytree': None, #overridden by feature_fraction
#        'min_child_samples': hp.quniform('min_child_samples', 20, 500, 5),
        'min_child_weight': hp.loguniform('min_child_weight', -16, 10), #also aliases to min_sum_hessian
        'metric': 'mae',
    }
    space['objective'] = "regression"

    global max_n
    max_n = max_n_search
    trials = Trials()
    best = fmin(fn=objective_sklearn,
                space=space,
                algo=tpe.suggest,
                max_evals=n_trials,
                trials=trials,
               verbose= 1)

    # find the trial with lowest loss value. this is what we consider the best one
    idx = np.argmin(trials.losses())
    print(idx)

    print(trials.trials[idx])

    # these should be the training parameters to use to achieve the best score in best trial
    params = trials.trials[idx]["result"]["params"]
    max_n = None

    print('==============================')
    print('= PARAMS')
    print('==============================')
    print(params)
    return params

# run a search
def run_lgb(X_cols, df_train, df_test, y_param, max_n=60000):
    global X
    global y
    y = y_param
    nrows = max_n

    X = df_train[X_cols]
    X_test = df_test[X_cols]

    # the param is the number of rows to use for training
    params = optimize_lgbm(max_n)
    print(params)

    return params

# %%
cols = df.drop(['price'], 1).columns
params = run_lgb(cols, df, df_test, df['price'])
# Out:
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] lambda_l2 is set=0.09266226750188268, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.09266226750188268
# [LightGBM] [Warning] bagging_fraction is set=0.904470280636971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.904470280636971
# [LightGBM] [Warning] lambda_l1 is set=0.28791397166299765, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.28791397166299765
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] lambda_l2 is set=0.09266226750188268, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.09266226750188268
# [LightGBM] [Warning] bagging_fraction is set=0.904470280636971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.904470280636971
# [LightGBM] [Warning] lambda_l1 is set=0.28791397166299765, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.28791397166299765
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] lambda_l2 is set=0.09266226750188268, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.09266226750188268
# [LightGBM] [Warning] bagging_fraction is set=0.904470280636971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.904470280636971
# [LightGBM] [Warning] lambda_l1 is set=0.28791397166299765, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.28791397166299765
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] lambda_l2 is set=0.09266226750188268, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.09266226750188268
# [LightGBM] [Warning] bagging_fraction is set=0.904470280636971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.904470280636971
# [LightGBM] [Warning] lambda_l1 is set=0.28791397166299765, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.28791397166299765
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] lambda_l2 is set=0.09266226750188268, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.09266226750188268
# [LightGBM] [Warning] bagging_fraction is set=0.904470280636971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.904470280636971
# [LightGBM] [Warning] lambda_l1 is set=0.28791397166299765, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.28791397166299765
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.19613514315798466, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.19613514315798466
# [LightGBM] [Warning] bagging_fraction is set=0.8761245124612372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8761245124612372
# [LightGBM] [Warning] lambda_l1 is set=0.2787365001821492, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2787365001821492
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.19613514315798466, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.19613514315798466
# [LightGBM] [Warning] bagging_fraction is set=0.8761245124612372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8761245124612372
# [LightGBM] [Warning] lambda_l1 is set=0.2787365001821492, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2787365001821492
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.19613514315798466, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.19613514315798466
# [LightGBM] [Warning] bagging_fraction is set=0.8761245124612372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8761245124612372
# [LightGBM] [Warning] lambda_l1 is set=0.2787365001821492, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2787365001821492
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.19613514315798466, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.19613514315798466
# [LightGBM] [Warning] bagging_fraction is set=0.8761245124612372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8761245124612372
# [LightGBM] [Warning] lambda_l1 is set=0.2787365001821492, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2787365001821492
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.19613514315798466, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.19613514315798466
# [LightGBM] [Warning] bagging_fraction is set=0.8761245124612372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8761245124612372
# [LightGBM] [Warning] lambda_l1 is set=0.2787365001821492, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2787365001821492
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.20017278136312003, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.20017278136312003
# [LightGBM] [Warning] bagging_fraction is set=0.9841767720366971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9841767720366971
# [LightGBM] [Warning] lambda_l1 is set=0.06911972607024147, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06911972607024147
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.20017278136312003, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.20017278136312003
# [LightGBM] [Warning] bagging_fraction is set=0.9841767720366971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9841767720366971
# [LightGBM] [Warning] lambda_l1 is set=0.06911972607024147, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06911972607024147
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.20017278136312003, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.20017278136312003
# [LightGBM] [Warning] bagging_fraction is set=0.9841767720366971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9841767720366971
# [LightGBM] [Warning] lambda_l1 is set=0.06911972607024147, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06911972607024147
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.20017278136312003, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.20017278136312003
# [LightGBM] [Warning] bagging_fraction is set=0.9841767720366971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9841767720366971
# [LightGBM] [Warning] lambda_l1 is set=0.06911972607024147, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06911972607024147
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.20017278136312003, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.20017278136312003
# [LightGBM] [Warning] bagging_fraction is set=0.9841767720366971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9841767720366971
# [LightGBM] [Warning] lambda_l1 is set=0.06911972607024147, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06911972607024147
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.10233649990563522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10233649990563522
# [LightGBM] [Warning] bagging_fraction is set=0.8806597855619971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8806597855619971
# [LightGBM] [Warning] lambda_l1 is set=0.22667497874394213, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.22667497874394213
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.10233649990563522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10233649990563522
# [LightGBM] [Warning] bagging_fraction is set=0.8806597855619971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8806597855619971
# [LightGBM] [Warning] lambda_l1 is set=0.22667497874394213, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.22667497874394213
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.10233649990563522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10233649990563522
# [LightGBM] [Warning] bagging_fraction is set=0.8806597855619971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8806597855619971
# [LightGBM] [Warning] lambda_l1 is set=0.22667497874394213, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.22667497874394213
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.10233649990563522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10233649990563522
# [LightGBM] [Warning] bagging_fraction is set=0.8806597855619971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8806597855619971
# [LightGBM] [Warning] lambda_l1 is set=0.22667497874394213, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.22667497874394213
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.10233649990563522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10233649990563522
# [LightGBM] [Warning] bagging_fraction is set=0.8806597855619971, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8806597855619971
# [LightGBM] [Warning] lambda_l1 is set=0.22667497874394213, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.22667497874394213
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] lambda_l2 is set=0.134560260073983, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.134560260073983
# [LightGBM] [Warning] bagging_fraction is set=0.8153640395657182, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8153640395657182
# [LightGBM] [Warning] lambda_l1 is set=0.07876573043689268, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.07876573043689268
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] lambda_l2 is set=0.134560260073983, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.134560260073983
# [LightGBM] [Warning] bagging_fraction is set=0.8153640395657182, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8153640395657182
# [LightGBM] [Warning] lambda_l1 is set=0.07876573043689268, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.07876573043689268
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] lambda_l2 is set=0.134560260073983, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.134560260073983
# [LightGBM] [Warning] bagging_fraction is set=0.8153640395657182, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8153640395657182
# [LightGBM] [Warning] lambda_l1 is set=0.07876573043689268, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.07876573043689268
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] lambda_l2 is set=0.134560260073983, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.134560260073983
# [LightGBM] [Warning] bagging_fraction is set=0.8153640395657182, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8153640395657182
# [LightGBM] [Warning] lambda_l1 is set=0.07876573043689268, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.07876573043689268
# [LightGBM] [Warning] bagging_freq is set=15, subsample_freq=0 will be ignored. Current value: bagging_freq=15
# [LightGBM] [Warning] lambda_l2 is set=0.134560260073983, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.134560260073983
# [LightGBM] [Warning] bagging_fraction is set=0.8153640395657182, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8153640395657182
# [LightGBM] [Warning] lambda_l1 is set=0.07876573043689268, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.07876573043689268
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.24476405054504483, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.24476405054504483
# [LightGBM] [Warning] bagging_fraction is set=0.8395273730722881, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8395273730722881
# [LightGBM] [Warning] lambda_l1 is set=0.0018701027358205779, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0018701027358205779
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.24476405054504483, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.24476405054504483
# [LightGBM] [Warning] bagging_fraction is set=0.8395273730722881, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8395273730722881
# [LightGBM] [Warning] lambda_l1 is set=0.0018701027358205779, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0018701027358205779
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.24476405054504483, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.24476405054504483
# [LightGBM] [Warning] bagging_fraction is set=0.8395273730722881, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8395273730722881
# [LightGBM] [Warning] lambda_l1 is set=0.0018701027358205779, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0018701027358205779
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.24476405054504483, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.24476405054504483
# [LightGBM] [Warning] bagging_fraction is set=0.8395273730722881, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8395273730722881
# [LightGBM] [Warning] lambda_l1 is set=0.0018701027358205779, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0018701027358205779
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.24476405054504483, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.24476405054504483
# [LightGBM] [Warning] bagging_fraction is set=0.8395273730722881, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8395273730722881
# [LightGBM] [Warning] lambda_l1 is set=0.0018701027358205779, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0018701027358205779
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.1787563367890835, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1787563367890835
# [LightGBM] [Warning] bagging_fraction is set=0.91051344744219, subsample=1.0 will be ignored. Current value: bagging_fraction=0.91051344744219
# [LightGBM] [Warning] lambda_l1 is set=0.16177336361659123, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.16177336361659123
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.1787563367890835, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1787563367890835
# [LightGBM] [Warning] bagging_fraction is set=0.91051344744219, subsample=1.0 will be ignored. Current value: bagging_fraction=0.91051344744219
# [LightGBM] [Warning] lambda_l1 is set=0.16177336361659123, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.16177336361659123
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.1787563367890835, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1787563367890835
# [LightGBM] [Warning] bagging_fraction is set=0.91051344744219, subsample=1.0 will be ignored. Current value: bagging_fraction=0.91051344744219
# [LightGBM] [Warning] lambda_l1 is set=0.16177336361659123, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.16177336361659123
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.1787563367890835, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1787563367890835
# [LightGBM] [Warning] bagging_fraction is set=0.91051344744219, subsample=1.0 will be ignored. Current value: bagging_fraction=0.91051344744219
# [LightGBM] [Warning] lambda_l1 is set=0.16177336361659123, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.16177336361659123
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.1787563367890835, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1787563367890835
# [LightGBM] [Warning] bagging_fraction is set=0.91051344744219, subsample=1.0 will be ignored. Current value: bagging_fraction=0.91051344744219
# [LightGBM] [Warning] lambda_l1 is set=0.16177336361659123, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.16177336361659123
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.04373120263300346, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04373120263300346
# [LightGBM] [Warning] bagging_fraction is set=0.933655708407348, subsample=1.0 will be ignored. Current value: bagging_fraction=0.933655708407348
# [LightGBM] [Warning] lambda_l1 is set=0.03175005413149855, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.03175005413149855
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.04373120263300346, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04373120263300346
# [LightGBM] [Warning] bagging_fraction is set=0.933655708407348, subsample=1.0 will be ignored. Current value: bagging_fraction=0.933655708407348
# [LightGBM] [Warning] lambda_l1 is set=0.03175005413149855, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.03175005413149855
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.04373120263300346, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04373120263300346
# [LightGBM] [Warning] bagging_fraction is set=0.933655708407348, subsample=1.0 will be ignored. Current value: bagging_fraction=0.933655708407348
# [LightGBM] [Warning] lambda_l1 is set=0.03175005413149855, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.03175005413149855
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.04373120263300346, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04373120263300346
# [LightGBM] [Warning] bagging_fraction is set=0.933655708407348, subsample=1.0 will be ignored. Current value: bagging_fraction=0.933655708407348
# [LightGBM] [Warning] lambda_l1 is set=0.03175005413149855, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.03175005413149855
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.04373120263300346, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04373120263300346
# [LightGBM] [Warning] bagging_fraction is set=0.933655708407348, subsample=1.0 will be ignored. Current value: bagging_fraction=0.933655708407348
# [LightGBM] [Warning] lambda_l1 is set=0.03175005413149855, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.03175005413149855
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.25906686267422185, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.25906686267422185
# [LightGBM] [Warning] bagging_fraction is set=0.9408393255353799, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9408393255353799
# [LightGBM] [Warning] lambda_l1 is set=0.24701730740992778, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.24701730740992778
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.25906686267422185, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.25906686267422185
# [LightGBM] [Warning] bagging_fraction is set=0.9408393255353799, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9408393255353799
# [LightGBM] [Warning] lambda_l1 is set=0.24701730740992778, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.24701730740992778
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.25906686267422185, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.25906686267422185
# [LightGBM] [Warning] bagging_fraction is set=0.9408393255353799, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9408393255353799
# [LightGBM] [Warning] lambda_l1 is set=0.24701730740992778, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.24701730740992778
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.25906686267422185, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.25906686267422185
# [LightGBM] [Warning] bagging_fraction is set=0.9408393255353799, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9408393255353799
# [LightGBM] [Warning] lambda_l1 is set=0.24701730740992778, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.24701730740992778
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.25906686267422185, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.25906686267422185
# [LightGBM] [Warning] bagging_fraction is set=0.9408393255353799, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9408393255353799
# [LightGBM] [Warning] lambda_l1 is set=0.24701730740992778, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.24701730740992778
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.14136006227510042, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14136006227510042
# [LightGBM] [Warning] bagging_fraction is set=0.9916468818201734, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9916468818201734
# [LightGBM] [Warning] lambda_l1 is set=0.024790472431763678, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.024790472431763678
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.14136006227510042, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14136006227510042
# [LightGBM] [Warning] bagging_fraction is set=0.9916468818201734, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9916468818201734
# [LightGBM] [Warning] lambda_l1 is set=0.024790472431763678, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.024790472431763678
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.14136006227510042, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14136006227510042
# [LightGBM] [Warning] bagging_fraction is set=0.9916468818201734, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9916468818201734
# [LightGBM] [Warning] lambda_l1 is set=0.024790472431763678, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.024790472431763678
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.14136006227510042, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14136006227510042
# [LightGBM] [Warning] bagging_fraction is set=0.9916468818201734, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9916468818201734
# [LightGBM] [Warning] lambda_l1 is set=0.024790472431763678, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.024790472431763678
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] lambda_l2 is set=0.14136006227510042, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14136006227510042
# [LightGBM] [Warning] bagging_fraction is set=0.9916468818201734, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9916468818201734
# [LightGBM] [Warning] lambda_l1 is set=0.024790472431763678, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.024790472431763678
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.18788913361045817, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18788913361045817
# [LightGBM] [Warning] bagging_fraction is set=0.8057575958118954, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8057575958118954
# [LightGBM] [Warning] lambda_l1 is set=0.2918944316218827, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2918944316218827
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.18788913361045817, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18788913361045817
# [LightGBM] [Warning] bagging_fraction is set=0.8057575958118954, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8057575958118954
# [LightGBM] [Warning] lambda_l1 is set=0.2918944316218827, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2918944316218827
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.18788913361045817, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18788913361045817
# [LightGBM] [Warning] bagging_fraction is set=0.8057575958118954, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8057575958118954
# [LightGBM] [Warning] lambda_l1 is set=0.2918944316218827, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2918944316218827
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.18788913361045817, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18788913361045817
# [LightGBM] [Warning] bagging_fraction is set=0.8057575958118954, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8057575958118954
# [LightGBM] [Warning] lambda_l1 is set=0.2918944316218827, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2918944316218827
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.18788913361045817, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18788913361045817
# [LightGBM] [Warning] bagging_fraction is set=0.8057575958118954, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8057575958118954
# [LightGBM] [Warning] lambda_l1 is set=0.2918944316218827, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2918944316218827
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.13683511089436398, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13683511089436398
# [LightGBM] [Warning] bagging_fraction is set=0.9607811424237647, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9607811424237647
# [LightGBM] [Warning] lambda_l1 is set=0.14351992283045473, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.14351992283045473
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.13683511089436398, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13683511089436398
# [LightGBM] [Warning] bagging_fraction is set=0.9607811424237647, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9607811424237647
# [LightGBM] [Warning] lambda_l1 is set=0.14351992283045473, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.14351992283045473
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.13683511089436398, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13683511089436398
# [LightGBM] [Warning] bagging_fraction is set=0.9607811424237647, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9607811424237647
# [LightGBM] [Warning] lambda_l1 is set=0.14351992283045473, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.14351992283045473
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.13683511089436398, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13683511089436398
# [LightGBM] [Warning] bagging_fraction is set=0.9607811424237647, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9607811424237647
# [LightGBM] [Warning] lambda_l1 is set=0.14351992283045473, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.14351992283045473
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.13683511089436398, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13683511089436398
# [LightGBM] [Warning] bagging_fraction is set=0.9607811424237647, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9607811424237647
# [LightGBM] [Warning] lambda_l1 is set=0.14351992283045473, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.14351992283045473
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.11610890268697385, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11610890268697385
# [LightGBM] [Warning] bagging_fraction is set=0.9434141206571023, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9434141206571023
# [LightGBM] [Warning] lambda_l1 is set=0.29110113485643174, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.29110113485643174
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.11610890268697385, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11610890268697385
# [LightGBM] [Warning] bagging_fraction is set=0.9434141206571023, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9434141206571023
# [LightGBM] [Warning] lambda_l1 is set=0.29110113485643174, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.29110113485643174
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.11610890268697385, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11610890268697385
# [LightGBM] [Warning] bagging_fraction is set=0.9434141206571023, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9434141206571023
# [LightGBM] [Warning] lambda_l1 is set=0.29110113485643174, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.29110113485643174
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.11610890268697385, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11610890268697385
# [LightGBM] [Warning] bagging_fraction is set=0.9434141206571023, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9434141206571023
# [LightGBM] [Warning] lambda_l1 is set=0.29110113485643174, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.29110113485643174
# [LightGBM] [Warning] bagging_freq is set=25, subsample_freq=0 will be ignored. Current value: bagging_freq=25
# [LightGBM] [Warning] lambda_l2 is set=0.11610890268697385, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11610890268697385
# [LightGBM] [Warning] bagging_fraction is set=0.9434141206571023, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9434141206571023
# [LightGBM] [Warning] lambda_l1 is set=0.29110113485643174, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.29110113485643174
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.2559055136160943, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2559055136160943
# [LightGBM] [Warning] bagging_fraction is set=0.8390945330737039, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8390945330737039
# [LightGBM] [Warning] lambda_l1 is set=0.1556670904820578, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1556670904820578
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.2559055136160943, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2559055136160943
# [LightGBM] [Warning] bagging_fraction is set=0.8390945330737039, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8390945330737039
# [LightGBM] [Warning] lambda_l1 is set=0.1556670904820578, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1556670904820578
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.2559055136160943, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2559055136160943
# [LightGBM] [Warning] bagging_fraction is set=0.8390945330737039, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8390945330737039
# [LightGBM] [Warning] lambda_l1 is set=0.1556670904820578, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1556670904820578
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.2559055136160943, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2559055136160943
# [LightGBM] [Warning] bagging_fraction is set=0.8390945330737039, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8390945330737039
# [LightGBM] [Warning] lambda_l1 is set=0.1556670904820578, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1556670904820578
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.2559055136160943, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2559055136160943
# [LightGBM] [Warning] bagging_fraction is set=0.8390945330737039, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8390945330737039
# [LightGBM] [Warning] lambda_l1 is set=0.1556670904820578, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1556670904820578
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.10655476600284557, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10655476600284557
# [LightGBM] [Warning] bagging_fraction is set=0.9149529166517993, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9149529166517993
# [LightGBM] [Warning] lambda_l1 is set=0.2464587825360433, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2464587825360433
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.10655476600284557, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10655476600284557
# [LightGBM] [Warning] bagging_fraction is set=0.9149529166517993, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9149529166517993
# [LightGBM] [Warning] lambda_l1 is set=0.2464587825360433, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2464587825360433
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.10655476600284557, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10655476600284557
# [LightGBM] [Warning] bagging_fraction is set=0.9149529166517993, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9149529166517993
# [LightGBM] [Warning] lambda_l1 is set=0.2464587825360433, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2464587825360433
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.10655476600284557, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10655476600284557
# [LightGBM] [Warning] bagging_fraction is set=0.9149529166517993, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9149529166517993
# [LightGBM] [Warning] lambda_l1 is set=0.2464587825360433, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2464587825360433
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.10655476600284557, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10655476600284557
# [LightGBM] [Warning] bagging_fraction is set=0.9149529166517993, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9149529166517993
# [LightGBM] [Warning] lambda_l1 is set=0.2464587825360433, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2464587825360433
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.06861806067016794, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.06861806067016794
# [LightGBM] [Warning] bagging_fraction is set=0.9038509534488172, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9038509534488172
# [LightGBM] [Warning] lambda_l1 is set=0.05479880342419815, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05479880342419815
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.06861806067016794, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.06861806067016794
# [LightGBM] [Warning] bagging_fraction is set=0.9038509534488172, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9038509534488172
# [LightGBM] [Warning] lambda_l1 is set=0.05479880342419815, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05479880342419815
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.06861806067016794, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.06861806067016794
# [LightGBM] [Warning] bagging_fraction is set=0.9038509534488172, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9038509534488172
# [LightGBM] [Warning] lambda_l1 is set=0.05479880342419815, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05479880342419815
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.06861806067016794, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.06861806067016794
# [LightGBM] [Warning] bagging_fraction is set=0.9038509534488172, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9038509534488172
# [LightGBM] [Warning] lambda_l1 is set=0.05479880342419815, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05479880342419815
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.06861806067016794, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.06861806067016794
# [LightGBM] [Warning] bagging_fraction is set=0.9038509534488172, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9038509534488172
# [LightGBM] [Warning] lambda_l1 is set=0.05479880342419815, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05479880342419815
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.2804963955509223, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2804963955509223
# [LightGBM] [Warning] bagging_fraction is set=0.8044327162088271, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8044327162088271
# [LightGBM] [Warning] lambda_l1 is set=0.13890266432063378, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.13890266432063378
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.2804963955509223, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2804963955509223
# [LightGBM] [Warning] bagging_fraction is set=0.8044327162088271, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8044327162088271
# [LightGBM] [Warning] lambda_l1 is set=0.13890266432063378, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.13890266432063378
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.2804963955509223, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2804963955509223
# [LightGBM] [Warning] bagging_fraction is set=0.8044327162088271, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8044327162088271
# [LightGBM] [Warning] lambda_l1 is set=0.13890266432063378, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.13890266432063378
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.2804963955509223, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2804963955509223
# [LightGBM] [Warning] bagging_fraction is set=0.8044327162088271, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8044327162088271
# [LightGBM] [Warning] lambda_l1 is set=0.13890266432063378, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.13890266432063378
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.2804963955509223, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2804963955509223
# [LightGBM] [Warning] bagging_fraction is set=0.8044327162088271, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8044327162088271
# [LightGBM] [Warning] lambda_l1 is set=0.13890266432063378, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.13890266432063378
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.15005820942928522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.15005820942928522
# [LightGBM] [Warning] bagging_fraction is set=0.9402681743207781, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9402681743207781
# [LightGBM] [Warning] lambda_l1 is set=0.17104022826999254, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.17104022826999254
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.15005820942928522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.15005820942928522
# [LightGBM] [Warning] bagging_fraction is set=0.9402681743207781, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9402681743207781
# [LightGBM] [Warning] lambda_l1 is set=0.17104022826999254, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.17104022826999254
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.15005820942928522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.15005820942928522
# [LightGBM] [Warning] bagging_fraction is set=0.9402681743207781, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9402681743207781
# [LightGBM] [Warning] lambda_l1 is set=0.17104022826999254, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.17104022826999254
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.15005820942928522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.15005820942928522
# [LightGBM] [Warning] bagging_fraction is set=0.9402681743207781, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9402681743207781
# [LightGBM] [Warning] lambda_l1 is set=0.17104022826999254, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.17104022826999254
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] lambda_l2 is set=0.15005820942928522, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.15005820942928522
# [LightGBM] [Warning] bagging_fraction is set=0.9402681743207781, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9402681743207781
# [LightGBM] [Warning] lambda_l1 is set=0.17104022826999254, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.17104022826999254
# [LightGBM] [Warning] bagging_freq is set=20, subsample_freq=0 will be ignored. Current value: bagging_freq=20
# [LightGBM] [Warning] lambda_l2 is set=0.2819298018815966, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2819298018815966
# [LightGBM] [Warning] bagging_fraction is set=0.8598228273728421, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8598228273728421
# [LightGBM] [Warning] lambda_l1 is set=0.27653420173601767, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.27653420173601767
# ...
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.17288264384535068, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.17288264384535068
# [LightGBM] [Warning] bagging_fraction is set=0.9582647514964954, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9582647514964954
# [LightGBM] [Warning] lambda_l1 is set=0.0767774951764437, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0767774951764437
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.17288264384535068, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.17288264384535068
# [LightGBM] [Warning] bagging_fraction is set=0.9582647514964954, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9582647514964954
# [LightGBM] [Warning] lambda_l1 is set=0.0767774951764437, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0767774951764437
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.17288264384535068, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.17288264384535068
# [LightGBM] [Warning] bagging_fraction is set=0.9582647514964954, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9582647514964954
# [LightGBM] [Warning] lambda_l1 is set=0.0767774951764437, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0767774951764437
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.17288264384535068, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.17288264384535068
# [LightGBM] [Warning] bagging_fraction is set=0.9582647514964954, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9582647514964954
# [LightGBM] [Warning] lambda_l1 is set=0.0767774951764437, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0767774951764437
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.17288264384535068, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.17288264384535068
# [LightGBM] [Warning] bagging_fraction is set=0.9582647514964954, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9582647514964954
# [LightGBM] [Warning] lambda_l1 is set=0.0767774951764437, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0767774951764437
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.23807398272972213, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.23807398272972213
# [LightGBM] [Warning] bagging_fraction is set=0.8611786824026224, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8611786824026224
# [LightGBM] [Warning] lambda_l1 is set=0.056255216503357346, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.056255216503357346
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.23807398272972213, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.23807398272972213
# [LightGBM] [Warning] bagging_fraction is set=0.8611786824026224, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8611786824026224
# [LightGBM] [Warning] lambda_l1 is set=0.056255216503357346, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.056255216503357346
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.23807398272972213, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.23807398272972213
# [LightGBM] [Warning] bagging_fraction is set=0.8611786824026224, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8611786824026224
# [LightGBM] [Warning] lambda_l1 is set=0.056255216503357346, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.056255216503357346
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.23807398272972213, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.23807398272972213
# [LightGBM] [Warning] bagging_fraction is set=0.8611786824026224, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8611786824026224
# [LightGBM] [Warning] lambda_l1 is set=0.056255216503357346, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.056255216503357346
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.23807398272972213, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.23807398272972213
# [LightGBM] [Warning] bagging_fraction is set=0.8611786824026224, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8611786824026224
# [LightGBM] [Warning] lambda_l1 is set=0.056255216503357346, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.056255216503357346
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.13937260754041492, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13937260754041492
# [LightGBM] [Warning] bagging_fraction is set=0.8792777108182994, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8792777108182994
# [LightGBM] [Warning] lambda_l1 is set=0.2666576287912752, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2666576287912752
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.13937260754041492, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13937260754041492
# [LightGBM] [Warning] bagging_fraction is set=0.8792777108182994, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8792777108182994
# [LightGBM] [Warning] lambda_l1 is set=0.2666576287912752, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2666576287912752
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.13937260754041492, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13937260754041492
# [LightGBM] [Warning] bagging_fraction is set=0.8792777108182994, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8792777108182994
# [LightGBM] [Warning] lambda_l1 is set=0.2666576287912752, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2666576287912752
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.13937260754041492, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13937260754041492
# [LightGBM] [Warning] bagging_fraction is set=0.8792777108182994, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8792777108182994
# [LightGBM] [Warning] lambda_l1 is set=0.2666576287912752, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2666576287912752
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.13937260754041492, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13937260754041492
# [LightGBM] [Warning] bagging_fraction is set=0.8792777108182994, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8792777108182994
# [LightGBM] [Warning] lambda_l1 is set=0.2666576287912752, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.2666576287912752
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.2084237522694697, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2084237522694697
# [LightGBM] [Warning] bagging_fraction is set=0.831566858182089, subsample=1.0 will be ignored. Current value: bagging_fraction=0.831566858182089
# [LightGBM] [Warning] lambda_l1 is set=0.09281122178977685, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.09281122178977685
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.2084237522694697, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2084237522694697
# [LightGBM] [Warning] bagging_fraction is set=0.831566858182089, subsample=1.0 will be ignored. Current value: bagging_fraction=0.831566858182089
# [LightGBM] [Warning] lambda_l1 is set=0.09281122178977685, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.09281122178977685
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.2084237522694697, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2084237522694697
# [LightGBM] [Warning] bagging_fraction is set=0.831566858182089, subsample=1.0 will be ignored. Current value: bagging_fraction=0.831566858182089
# [LightGBM] [Warning] lambda_l1 is set=0.09281122178977685, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.09281122178977685
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.2084237522694697, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2084237522694697
# [LightGBM] [Warning] bagging_fraction is set=0.831566858182089, subsample=1.0 will be ignored. Current value: bagging_fraction=0.831566858182089
# [LightGBM] [Warning] lambda_l1 is set=0.09281122178977685, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.09281122178977685
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.2084237522694697, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.2084237522694697
# [LightGBM] [Warning] bagging_fraction is set=0.831566858182089, subsample=1.0 will be ignored. Current value: bagging_fraction=0.831566858182089
# [LightGBM] [Warning] lambda_l1 is set=0.09281122178977685, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.09281122178977685
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.19472496076537713, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.19472496076537713
# [LightGBM] [Warning] bagging_fraction is set=0.9105635605004372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9105635605004372
# [LightGBM] [Warning] lambda_l1 is set=0.04834702490250844, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04834702490250844
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.19472496076537713, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.19472496076537713
# [LightGBM] [Warning] bagging_fraction is set=0.9105635605004372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9105635605004372
# [LightGBM] [Warning] lambda_l1 is set=0.04834702490250844, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04834702490250844
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.19472496076537713, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.19472496076537713
# [LightGBM] [Warning] bagging_fraction is set=0.9105635605004372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9105635605004372
# [LightGBM] [Warning] lambda_l1 is set=0.04834702490250844, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04834702490250844
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.19472496076537713, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.19472496076537713
# [LightGBM] [Warning] bagging_fraction is set=0.9105635605004372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9105635605004372
# [LightGBM] [Warning] lambda_l1 is set=0.04834702490250844, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04834702490250844
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] lambda_l2 is set=0.19472496076537713, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.19472496076537713
# [LightGBM] [Warning] bagging_fraction is set=0.9105635605004372, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9105635605004372
# [LightGBM] [Warning] lambda_l1 is set=0.04834702490250844, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04834702490250844
# 100%|██████████| 200/200 [1:39:09<00:00, 29.75s/trial, best loss: 644036.1581950441]
# 59
# {'state': 2, 'tid': 59, 'spec': None, 'result': {'loss': 644036.1581950441, 'score': 644036.1581950441, 'params': {'bagging_fraction': 0.8876911520616036, 'bagging_freq': 5, 'boosting_type': 'gbdt', 'colsample_bytree': None, 'feature_fraction': 0.8568055674122264, 'lambda_l1': 0.11085417960346233, 'lambda_l2': 0.21631191989432652, 'learning_rate': 0.15926206787675018, 'metric': 'mae', 'min_child_samples': None, 'min_child_weight': 0.0002629359348261388, 'min_data_in_leaf': 0, 'min_sum_hessian_in_leaf': None, 'num_leaves': 328, 'objective': 'regression', 'seed': 42, 'subsample_for_bin': 2800, 'verbose': -1, 'n_estimators': 10000}, 'status': 'ok'}, 'misc': {'tid': 59, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'bagging_fraction': [59], 'bagging_freq': [59], 'boosting_type': [59], 'feature_fraction': [59], 'lambda_l1': [59], 'lambda_l2': [59], 'learning_rate': [59], 'min_child_weight': [59], 'min_data_in_leaf': [59], 'num_leaves': [59], 'subsample_for_bin': [59]}, 'vals': {'bagging_fraction': [0.8876911520616036], 'bagging_freq': [5.0], 'boosting_type': [0], 'feature_fraction': [0.8568055674122264], 'lambda_l1': [0.11085417960346233], 'lambda_l2': [0.21631191989432652], 'learning_rate': [0.15926206787675018], 'min_child_weight': [0.0002629359348261388], 'min_data_in_leaf': [0.0], 'num_leaves': [328.0], 'subsample_for_bin': [2800.0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2021, 8, 24, 17, 38, 8, 901000), 'refresh_time': datetime.datetime(2021, 8, 24, 17, 38, 37, 329000)}
# ==============================
# = PARAMS
# ==============================
# {'bagging_fraction': 0.8876911520616036, 'bagging_freq': 5, 'boosting_type': 'gbdt', 'colsample_bytree': None, 'feature_fraction': 0.8568055674122264, 'lambda_l1': 0.11085417960346233, 'lambda_l2': 0.21631191989432652, 'learning_rate': 0.15926206787675018, 'metric': 'mae', 'min_child_samples': None, 'min_child_weight': 0.0002629359348261388, 'min_data_in_leaf': 0, 'min_sum_hessian_in_leaf': None, 'num_leaves': 328, 'objective': 'regression', 'seed': 42, 'subsample_for_bin': 2800, 'verbose': -1, 'n_estimators': 10000}
# {'bagging_fraction': 0.8876911520616036, 'bagging_freq': 5, 'boosting_type': 'gbdt', 'colsample_bytree': None, 'feature_fraction': 0.8568055674122264, 'lambda_l1': 0.11085417960346233, 'lambda_l2': 0.21631191989432652, 'learning_rate': 0.15926206787675018, 'metric': 'mae', 'min_child_samples': None, 'min_child_weight': 0.0002629359348261388, 'min_data_in_leaf': 0, 'min_sum_hessian_in_leaf': None, 'num_leaves': 328, 'objective': 'regression', 'seed': 42, 'subsample_for_bin': 2800, 'verbose': -1, 'n_estimators': 10000}
